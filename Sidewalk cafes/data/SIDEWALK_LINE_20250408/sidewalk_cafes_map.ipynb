# %%
import pandas as pd

# Load the CSV file (make sure the file is in your current working directory or provide the full path)
df = pd.read_csv("SIDEWALK_LINE_20250408.csv")

# Display the top 10 rows of the dataframe
df.head(10)
# Out:
# D:\TEMP_FILES\ipykernel_19576\2422472785.py:4: DtypeWarning: Columns (2,3,4,5,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("SIDEWALK_LINE_20250408.csv")
#                                             the_geom  PHYSICALID L_LOW_HN  \
# 0  MULTILINESTRING ((-74.01793061274537 40.706174...           3       50
# 1  MULTILINESTRING ((-74.01757437049282 40.706839...           5       66
# 2  MULTILINESTRING ((-74.01712051881411 40.707462...           6       84
# 3  MULTILINESTRING ((-74.01693786186667 40.704813...           8      NaN
# 4  MULTILINESTRING ((-74.01428922948978 40.704549...          14      NaN
# 5  MULTILINESTRING ((-74.01739796591468 40.708457...          23      300
# 6  MULTILINESTRING ((-74.01662578576105 40.708133...          24      200
# 7  MULTILINESTRING ((-74.01616698119132 40.707904...          25      136
# 8  MULTILINESTRING ((-74.01699521616094 40.705800...          29      NaN
# ...

# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt

# Load CSV
df = pd.read_csv("SIDEWALK_LINE_20250408.csv")

# Convert WKT geometries to Shapely objects
df["geometry"] = df["the_geom"].apply(wkt.loads)

# Drop the original 'the_geom' column
df = df.drop(columns=["the_geom"])

# Create GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

# Export to GeoJSON
gdf.to_file("sidewalk_lines.geojson", driver="GeoJSON")
# Out:
# D:\TEMP_FILES\ipykernel_19576\368069686.py:6: DtypeWarning: Columns (2,3,4,5,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("SIDEWALK_LINE_20250408.csv")
